# %%
setwd('/Users/alexis/IEHS Dropbox/Rager Lab/Alexis_Payton/Experiments/3. Plasma Microvesicles/Input')
cur_date = "060321"

library(readxl)
library(tidyverse)
library(reshape2)
library(patchwork)

#reading in files
exp_details = data.frame(read_excel("Experiment_Details_052521.xlsx"))
mrna_details = data.frame(read_excel("MRNA_Details_052521.xlsx"))
mirna_details = data.frame(read_excel("MiRNA_Details_052521.xlsx"))
protein_functions = data.frame(read_excel("Protein Functions.xlsx", sheet = 1))
# Out:
# ── Attaching packages ─────────────────────────────────────── tidyverse 1.3.0 ──
#
# ✔ ggplot2 3.3.3     ✔ purrr   0.3.4
# ✔ tibble  3.0.6     ✔ dplyr   1.0.4
# ✔ tidyr   1.1.2     ✔ stringr 1.4.0
# ✔ readr   1.4.0     ✔ forcats 0.5.1
#
# ── Conflicts ────────────────────────────────────────── tidyverse_conflicts() ──
# ✖ dplyr::filter() masks stats::filter()
# ✖ dplyr::lag()    masks stats::lag()
#
#
# Attaching package: ‘reshape2’
#
#
# The following object is masked from ‘package:tidyr’:
#
#     smiths

# %%
#first combining all these files to see what mrnas/ mirnas are associated with microvesicles
mrna_data = inner_join(exp_details, mrna_details) %>%
    #removing variables that aren't necessary 
    select(-c('EXPERIMENT.DESCRIPTION', 'CONTENT.ID'))
head(mrna_data)

mirna_data = inner_join(exp_details, mirna_details) %>%
    #removing variables that aren't necessary 
    select(-c('EXPERIMENT.DESCRIPTION', 'CONTENT.ID'))
head(mirna_data)
# Out:
# Joining, by = c("EXPERIMENT.ID", "SPECIES", "METHODS")
#   EXPERIMENT.ID PUBMED.ID SPECIES      SAMPLE.NAME
# 1  43           17076679  Homo sapiens Plasma - Pregnant and not-pregnant women
# 2  43           17076679  Homo sapiens Plasma - Pregnant and not-pregnant women
# 3  43           17076679  Homo sapiens Plasma - Pregnant and not-pregnant women
# 4  68           19619303  Homo sapiens Plasma - Ovarian cancer
# 5 199           21609964  Homo sapiens Plasma - Normal
# 6 353           24115447  Homo sapiens Plasma - Normal
#   IDENTIFICATIONS METHODS                                             YEAR
# 1 Protein         Western blotting                                    2006
# 2 Protein         Western blotting                                    2006
# 3 Protein         Western blotting                                    2006
# 4 Protein         Western blotting                                    2009
# 5 Protein         Western blotting                                    2011
# 6 Protein         Mass spectrometry [Orbitrap Velos]|Western blotting 2013
#   ISOLATION.METHOD
# 1 Size exclusion chromatography|Ultracentrifugation|Immunobeads (CD3, CD19, CD56, CD83, PLAP)
# 2 Size exclusion chromatography|Ultracentrifugation|Immunobeads (CD3, CD19, CD56, CD83, PLAP)
# 3 Size exclusion chromatography|Ultracentrifugation|Immunobeads (CD3, CD19, CD56, CD83, PLAP)
# 4 Differential centrifugation
# 5 Differential centrifugation|Filtration
# 6 Differential centrifugation|Filtration|Ultracentrifugation
#   VESICLE.TYPE CONTENT.TYPE ENTREZ.GENE.ID GENE.SYMBOL
# 1 Exosomes     protein        250          ALPP
# 2 Exosomes     protein        356          FASLG
# 3 Exosomes     protein      29126          CD274
# 4 Exosomes     protein       1364          CLDN4
# 5 Exosomes     protein        928          CD9
# 6 Exosomes     protein       7037          TFRC
# Joining, by = c("EXPERIMENT.ID", "SPECIES", "METHODS")
#   EXPERIMENT.ID PUBMED.ID SPECIES      SAMPLE.NAME
# 1 325           19289371  Homo sapiens Plasma -  Lung adenocarcinoma patients
# 2 325           19289371  Homo sapiens Plasma -  Lung adenocarcinoma patients
# 3 325           19289371  Homo sapiens Plasma -  Lung adenocarcinoma patients
# 4 325           19289371  Homo sapiens Plasma -  Lung adenocarcinoma patients
# 5 325           19289371  Homo sapiens Plasma -  Lung adenocarcinoma patients
# 6 325           19289371  Homo sapiens Plasma -  Lung adenocarcinoma patients
#   IDENTIFICATIONS METHODS    YEAR
# 1 miRNA           Microarray 2009
# 2 miRNA           Microarray 2009
# 3 miRNA           Microarray 2009
# 4 miRNA           Microarray 2009
# 5 miRNA           Microarray 2009
# 6 miRNA           Microarray 2009
#   ISOLATION.METHOD                                  VESICLE.TYPE CONTENT.TYPE
# 1 Size exclusion chromatography|Immunobeads (EpCAM) Exosomes     mirna
# 2 Size exclusion chromatography|Immunobeads (EpCAM) Exosomes     mirna
# 3 Size exclusion chromatography|Immunobeads (EpCAM) Exosomes     mirna
# 4 Size exclusion chromatography|Immunobeads (EpCAM) Exosomes     mirna
# 5 Size exclusion chromatography|Immunobeads (EpCAM) Exosomes     mirna
# 6 Size exclusion chromatography|Immunobeads (EpCAM) Exosomes     mirna
#   MIRNA.ID  Entrez.GENE.ID COMMENTS
# 1 miR-17-3p 406952         Ambiguous mapping to Entrez gene ID
# 2 miR-21    406991         Clear hit to Entrez gene ID
# 3 miR-106a  406899         Clear hit to Entrez gene ID
# 4 miR-146   NOTFOUND       NOTFOUND
# 5 miR-155   406947         Clear hit to Entrez gene ID
# 6 miR-191   406966         Clear hit to Entrez gene ID

# %% [markdown]
# # How many proteins or miRNAs have been identified?

# %%
#we're dealing with 1,512 unique genes and 143 unique miRNAs so visualizations might be a bit challenging
length(unique(mrna_data$GENE.SYMBOL))
length(unique(mirna_data$MIRNA.ID))
# Out:
# [1] 1512
# [1] 143

# %% [markdown]
# # From how many unique publications?

# %%
length(unique(mrna_data$PUBMED.ID))
length(unique(mirna_data$PUBMED.ID))
# Out:
# [1] 28
# [1] 5

# %%
#did some rearranging so the dataframes match
all_data = data.frame(rbind(mrna_data %>%
                        rename(ID = GENE.SYMBOL),
                        mirna_data %>%
                        select(-COMMENTS) %>%
                        rename(ID = MIRNA.ID, ENTREZ.GENE.ID = Entrez.GENE.ID)))

publication_count = all_data %>%
    group_by(CONTENT.TYPE, PUBMED.ID) %>%
    count() %>%
    arrange(CONTENT.TYPE, -n)

head(publication_count)
# Out:
#   CONTENT.TYPE PUBMED.ID n
# 1 mirna        19002258   76
# 2 mirna        28357077   60
# 3 mirna        19289371   12
# 4 mirna        19951903    6
# 5 mirna        25104112    2
# 6 protein      23056467  956

# %%
options(repr.plot.width=18, repr.plot.height=8) #changing size
ggplot(data = publication_count, aes(x = n, y = reorder(PUBMED.ID, n), fill = CONTENT.TYPE, color = CONTENT.TYPE)) + 
  geom_col() + 
  geom_text(aes(label = n, color = CONTENT.TYPE), position = position_dodge(width = 0.9), hjust = -0.2) +
  facet_wrap(~CONTENT.TYPE, scales = 'free') + 
  labs(y = 'Pubmed Id')
# Out:
# plot without title

# %% [markdown]
# # How many proteins or miRNAs have been identified by species?

# %%
options(repr.plot.width=15, repr.plot.height=7) #changing size
species_count = all_data %>%
    group_by(CONTENT.TYPE, SPECIES) %>%
    count()

ggplot(data = species_count, aes(y = n, x = reorder(SPECIES, n), fill = CONTENT.TYPE, color = CONTENT.TYPE)) + 
  geom_col(position = 'dodge') + 
  geom_text(aes(label = n, color = CONTENT.TYPE), position = position_dodge(width = 0.9), vjust = -0.2) + 
  facet_wrap(~CONTENT.TYPE, scales = 'free_x') + 
  #rotating x labels/ moving x labels slightly to the left
  theme(axis.text.x = element_text(angle = 45, vjust = 0.9, hjust = 0.99)) + 
  labs(y = 'Species')
# Out:
# plot without title

# %% [markdown]
# # How many proteins or miRNAs have been identified by vesicle type?

# %%
vesicle_type_count = all_data %>%
    group_by(CONTENT.TYPE, VESICLE.TYPE) %>%
    #just for humans
    filter(SPECIES == 'Homo sapiens') %>%
    count()

ggplot(data = vesicle_type_count, aes(y = n, x = reorder(VESICLE.TYPE, n), fill = CONTENT.TYPE, 
                                 color = CONTENT.TYPE)) + 
  geom_col(position = 'dodge') + 
  geom_text(aes(label = n, color = CONTENT.TYPE), position = position_dodge(width = 0.9), vjust = -0.2) + 
  facet_wrap(~CONTENT.TYPE, scales = 'free') + 
  #rotating x labels/ moving x labels slightly to the left
  theme(axis.text.x = element_text(angle = 45, vjust = 0.9, hjust = 0.9999)) +
  labs(y = 'Vesicle Type')
# Out:
# plot without title

# %% [markdown]
# # What proteins or miRNAs have been identified the most frequently?

# %%
mrna_count = mrna_data %>%
    #just for humans
    filter(SPECIES == 'Homo sapiens') %>%
    group_by(GENE.SYMBOL) %>%
    count() %>%
    arrange(-n) %>%
    filter(n >= 10) #just plotting the most frequent mrnas (>= 10)
mrna_count = full_join(mrna_count, protein_functions[,1:2], by = c("GENE.SYMBOL" = "Protein")) %>%
    arrange(Function,n)
head(mrna_count)
# Out:
#   GENE.SYMBOL n  Function
# 1 CD5L        10 apoptosis
# 2 ALB         12 apoptosis
# 3 A2M         10 blood coagulation
# 4 ANXA5       10 blood coagulation
# 5 GP1BA       10 blood coagulation
# 6 FN1         11 blood coagulation

# %%
#grouped by category
options(repr.plot.width=12, repr.plot.height=7) #changing size
gene_levels = rev(mrna_count$GENE.SYMBOL) #had to reverse these levels to match the legend
ggplot(data = mrna_count, aes(x = n, y = factor(GENE.SYMBOL, levels = gene_levels), 
                              color = Function, fill = Function)) + 
  geom_col() + 
  geom_text(aes(label = n), position = position_dodge(width = 0.9), hjust = -0.2) + 

  theme_bw() + #changing theme
  theme(axis.text = element_text(size = 12), #changing size of x axis labels
        axis.title = element_text(face = "bold", size = rel(1.7)), #changes axis titles
        legend.title = element_text(face = "bold", size = 15),
        legend.text = element_text(size = 12)) + 
  labs(y = 'Protein', x = "Number of Publication Identifications")
# Out:
# plot without title

# %%
#grouped by number of identifications
options(repr.plot.width=12, repr.plot.height=7) #changing size
protein_publications_graph = ggplot(data = mrna_count, aes(x = n, y = reorder(GENE.SYMBOL, n), 
                              color = Function, fill = Function)) + 
  geom_col() + 
  geom_text(aes(label = n), position = position_dodge(width = 0.9), hjust = -0.2) + 

  theme_bw() + #changing theme
  theme(axis.text = element_text(size = 12), #changing size of x axis labels
        axis.title = element_text(face = "bold", size = rel(1.7)), #changes axis titles
        axis.title.x = element_text(vjust = 22), #need this in order to not have space in patchwork
        legend.title = element_text(face = "bold", size = 15),
        legend.position = c(0.455,-0.25), #moves legend to the bottom
        legend.direction = "horizontal", #makes legend horizontal
        legend.background = element_rect(colour = 'black', fill = 'white', linetype = 'solid'),
        legend.text = element_text(size = 12)) + 
  labs(y = 'Protein', x = "Number of Publication Identifications")

protein_publications_graph
# Out:
# plot without title

# %%
mrna_count = mrna_data %>%
    #just for humans
    filter(SPECIES == 'Homo sapiens') %>%
    group_by(GENE.SYMBOL) %>%
    count() %>%
    arrange(-n) %>%
    filter(n >= 10) #just plotting the most frequent mrnas (>= 10)
mrna_count = full_join(mrna_count, protein_functions[,1:2], by = c("GENE.SYMBOL" = "Protein")) %>%
    arrange(Function,n)
head(mrna_count)
# Out:
#   GENE.SYMBOL n  Function
# 1 CD5L        10 apoptosis
# 2 ALB         12 apoptosis
# 3 A2M         10 blood coagulation
# 4 ANXA5       10 blood coagulation
# 5 GP1BA       10 blood coagulation
# 6 FN1         11 blood coagulation

# %%
#now just creating the same bar chart above w/o the functions
options(repr.plot.width=12, repr.plot.height=7) #changing size
ggplot(data = mrna_count, aes(x = n, y = reorder(GENE.SYMBOL, n))) + 
  geom_col() + 
  geom_text(aes(label = n), position = position_dodge(width = 0.9), hjust = -0.2) + 

  theme_bw() + #changing theme
  theme(axis.text = element_text(size = 12), #changing size of x axis labels
        axis.title = element_text(face = "bold", size = rel(1.7)), #changes axis titles
        legend.title = element_text(face = "bold", size = 15),
        legend.text = element_text(size = 12)) + 
  labs(y = 'Protein', x = "Number of Publication Identifications")
# Out:
# plot without title

# %%
mirna_count = mirna_data %>%
    #just for humans
    filter(SPECIES == 'Homo sapiens') %>%
    group_by(MIRNA.ID) %>%
    count() %>%
    arrange(-n) %>%
    filter(n >= 2) #just plotting the most frequent mirnas (>= 2)

ggplot(data = mirna_count, aes(x = n, y = reorder(MIRNA.ID, n))) + 
  geom_col() + 
  geom_text(aes(label = n), position = position_dodge(width = 0.9), hjust = -0.2) + 
  labs(y = 'miRNA')
# Out:
# plot without title

# %% [markdown]
# # What functions are associated with each protein or mirna?

# %%
#now making heat map of protein functions
melted_protein_functions = data.frame(read_excel("Protein Functions.xlsx", sheet = 2)) %>%
    #column_to_rownames(var = "Protein") %>%
    reshape2::melt(id = "Protein", variable = "Function", value.name = "Value")
head(melted_protein_functions)

#also sorting the df by avg value for protein and function to order the heat map
ordered_protein_df = melted_protein_functions %>%
    group_by(Protein) %>%
    summarize(Avg_Value = mean(Value)) %>%
    #highest to lowest avg protein value
    arrange(desc(Avg_Value))
ordered_proteins = ordered_protein_df$Protein


ordered_functions_df = melted_protein_functions %>%
    group_by(Function) %>%
    summarize(Avg_Value = mean(Value)) %>%
    #highest to lowest avg function value
    arrange(desc(Avg_Value))
ordered_functions = ordered_functions_df$Function
# Out:
#   Protein Function        Value
# 1 FGA     immune_response 1
# 2 PECAM1  immune_response 0
# 3 HPR     immune_response 0
# 4 FGG     immune_response 0
# 5 C1QC    immune_response 1
# 6 ALB     immune_response 0

# %%
options(repr.plot.width=12, repr.plot.height=7) #changing size
publication_levels = levels(reorder(mrna_count$GENE.SYMBOL, mrna_count$n))
protein_heat_map = ggplot(data = melted_protein_functions, aes(x = factor(Function, levels = ordered_functions), 
                                            y = factor(Protein, levels = publication_levels), 
                                            #need to figure out how to make this binary 
                                            fill = Value)) + 
  geom_tile(color = 'white') + 
  scale_fill_gradient(low = "#00436f", high = "#00a9dd") +
  
  theme_minimal() + #changing theme
  theme(axis.text = element_text(size = 12), #changing size of x axis labels
        axis.title = element_text(face = "bold", size = rel(1.7)), #changes axis titles
        legend.position = "none", #removing legend 
        legend.text = element_text(size = 12),
        #rotating x labels/ moving x labels slightly to the left
        axis.text.x = element_text(angle = 45, hjust = 0.9999),
        axis.title.y = element_blank()) + #removes y axis title

  labs(x = "Function", fill = "Function")

protein_heat_map
# Out:
# plot without title

# %% [markdown]
# # Protein/miRNA Function and Publication Identifications

# %%
#protein heat map and identifications
options(repr.plot.width=18, repr.plot.height=7) #changing size

protein_publications_graph + protein_heat_map
# Out:
# plot without title
